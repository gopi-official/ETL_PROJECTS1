# %% [markdown]
# SQL_QUERYS

# %% [markdown]
# CREATE TABLE customers (
#     CustomerID SERIAL PRIMARY KEY,
#     Age INT,
#     Gender VARCHAR(10),
#     Income DECIMAL(10, 2),
#     SpendingScore INT CHECK (SpendingScore BETWEEN 1 AND 100),
#     EducationLevel VARCHAR(50),
#     MaritalStatus VARCHAR(20),
#     NumberOfDependents INT,
#     Tenure INT,
#     AccountType VARCHAR(50),
#     PreferredChannel VARCHAR(50),
#     PurchaseFrequency VARCHAR(50),
#     ProductCategory VARCHAR(50),
#     AverageTransactionValue DECIMAL(10, 2),
#     TotalTransactions INT,
#     LoyaltyScore INT CHECK (LoyaltyScore BETWEEN 1 AND 100),
#     CustomerLifetimeValue DECIMAL(10, 2),
#     Region VARCHAR(50),
#     SatisfactionScore INT CHECK (SatisfactionScore BETWEEN 1 AND 100),
#     LastPurchaseDate DATE,
#     AvgDailyVisits DECIMAL(5, 2),
#     AvgMonthlySpend DECIMAL(10, 2),
#     ChurnRisk VARCHAR(20),
#     CampaignResponse VARCHAR(50),
#     PreferredPaymentMethod VARCHAR(50)
# );
#
#
# SELECT * from customers
#
#
#
#
# select current_user,now()
#
# SELECT usename FROM pg_user;
#
# ALTER USER postgres WITH PASSWORD 'newpassword';
#
# CREATE USER username WITH PASSWORD 'newpassword';

# %% [markdown]
# sql querys

# %% [markdown]
# POSTGRESQL TO PYTHON

# %%
pip install sqlalchemy
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\leowa\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install psycopg2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\leowa\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Replace with your MySQL connection details
username = 'postgres'
password = 'newpassword'
host = 'localhost'
port = '5432'
database_name = 'privasapien'

# %%
import psycopg2
engine = create_engine(f'postgresql://{username}:{password}@{host}:{port}/{database_name}')

# %%
import pandas as pd
query = "select * from customers"

df = pd.read_sql(query,engine)

print(df)
# Out:
#         customerid  age gender    income  spendingscore educationlevel  \
# 0           100001   56      F  102681.0             36       Master's
# 1           100002   69      F   99188.0             44     Bachelor's
# 2           100003   46      M   67800.0             31       Master's
# 3           100004   32      F   40549.0             97       Master's
# 4           100005   60      F   29482.0             67       Master's
# ...            ...  ...    ...       ...            ...            ...
# 199995      299996   63      M   25128.0              7     Bachelor's
# 199996      299997   38      M  111611.0             46    High School
# 199997      299998   62      M  106989.0             42       Master's
# 199998      299999   41      F   58197.0             49     Bachelor's
# 199999      300000   61      M   59834.0             39    High School
#
#        maritalstatus  numberofdependents  tenure accounttype  ...  \
# ...

# %%
df
# Out:
#         customerid  age gender    income  spendingscore educationlevel  \
# 0           100001   56      F  102681.0             36       Master's
# 1           100002   69      F   99188.0             44     Bachelor's
# 2           100003   46      M   67800.0             31       Master's
# 3           100004   32      F   40549.0             97       Master's
# 4           100005   60      F   29482.0             67       Master's
# ...            ...  ...    ...       ...            ...            ...
# 199995      299996   63      M   25128.0              7     Bachelor's
# 199996      299997   38      M  111611.0             46    High School
# 199997      299998   62      M  106989.0             42       Master's
# 199998      299999   41      F   58197.0             49     Bachelor's
# 199999      300000   61      M   59834.0             39    High School
#
#        maritalstatus  numberofdependents  tenure accounttype  ...  \
# ...

# %% [markdown]
# PANDAS TO PYSPARK

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName("ETL").getOrCreate()

# %%
pyspark_df = spark.createDataFrame(df)

# %%
pyspark_df.show()
# Out:
# +----------+---+------+--------+-------------+--------------+-------------+------------------+------+-----------+----------------+-----------------+---------------+-----------------------+-----------------+------------+---------------------+------+-----------------+----------------+--------------+---------------+---------+----------------+----------------------+
# |customerid|age|gender|  income|spendingscore|educationlevel|maritalstatus|numberofdependents|tenure|accounttype|preferredchannel|purchasefrequency|productcategory|averagetransactionvalue|totaltransactions|loyaltyscore|customerlifetimevalue|region|satisfactionscore|lastpurchasedate|avgdailyvisits|avgmonthlyspend|churnrisk|campaignresponse|preferredpaymentmethod|
# ...

# %%
pyspark_df.columns
# Out:
# ['customerid',
#  'age',
#  'gender',
#  'income',
#  'spendingscore',
#  'educationlevel',
#  'maritalstatus',
#  'numberofdependents',
#  'tenure',
#  'accounttype',
#  'preferredchannel',
#  'purchasefrequency',
#  'productcategory',
#  'averagetransactionvalue',
#  'totaltransactions',
#  'loyaltyscore',
#  'customerlifetimevalue',
#  'region',
#  'satisfactionscore',
#  'lastpurchasedate',
#  'avgdailyvisits',
#  'avgmonthlyspend',
#  'churnrisk',
#  'campaignresponse',
#  'preferredpaymentmethod']

# %%
x = pyspark_df.select('customerid','age','income','spendingscore','numberofdependents','tenure','purchasefrequency','averagetransactionvalue','totaltransactions','loyaltyscore','customerlifetimevalue','satisfactionscore','lastpurchasedate','avgdailyvisits','avgmonthlyspend',)
x.show()
y = pyspark_df.select('gender','educationlevel','maritalstatus','accounttype','preferredchannel','productcategory', 'region','churnrisk','campaignresponse','preferredpaymentmethod')
y.show()
# Out:
# +----------+---+--------+-------------+------------------+------+-----------------+-----------------------+-----------------+------------+---------------------+-----------------+----------------+--------------+---------------+
# |customerid|age|  income|spendingscore|numberofdependents|tenure|purchasefrequency|averagetransactionvalue|totaltransactions|loyaltyscore|customerlifetimevalue|satisfactionscore|lastpurchasedate|avgdailyvisits|avgmonthlyspend|
# +----------+---+--------+-------------+------------------+------+-----------------+-----------------------+-----------------+------------+---------------------+-----------------+----------------+--------------+---------------+
# |    100001| 56|102681.0|           36|                 3|     6|                8|                  156.0|              146|          93|               3915.0|               64|      2023-05-06|           6.0|          633.0|
# ...

# %% [markdown]
# PYSPARK TO UPLOAD S3 BUCKET    ------------------------    x=numerical columns

# %%
pip install boto3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\leowa\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import boto3
from io import StringIO

# %%
#Convert the PySpark DataFrame to Pandas (for CSV conversion)
x_pd = x.toPandas()

# %%
#Convert the Pandas DataFrame to CSV (you can use Parquet too)
csv_buffer = StringIO()
x_pd.to_csv(csv_buffer, index=False)

# %%
s3_client = boto3.client(
    service_name='s3',
    region_name='us-east-2',
    aws_access_key_id='AKIAZYXIBCG3F6SPCPXH',
    aws_secret_access_key='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'
)

# %%
bucket_name ='etl-extractdata'
file_name = 'customer_segmentation/numerical.csv'

# %%
s3_client.put_object(
    Bucket=bucket_name,
    Key=file_name,
    Body=csv_buffer.getvalue()
)

print(f"File uploaded to {bucket_name}/{file_name}")
# Out:
# File uploaded to etl-extractdata/customer_segmentation/numerical.csv

# %% [markdown]
# PYSPARK TO UPLOAD S3 BUCKET    ------------------------    y=categorical columns

# %%
import pandas as pd
import boto3
from io import StringIO

# %%
#Convert the PySpark DataFrame to Pandas (for CSV conversion)
y_pd=y.toPandas()

# %%
#Convert the Pandas DataFrame to CSV (you can use Parquet too)
csv_buffer1 = StringIO()
y_pd.to_csv(csv_buffer1,index=False)

# %%
s3_client = boto3.client(
    service_name='s3',
    region_name='us-east-2',
    aws_access_key_id='AKIAZYXIBCG3F6SPCPXH',
    aws_secret_access_key='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'
)

# %%
bucket_name ='etl-extractdata'
file_name = 'customer_segmentation/categorical.csv'

# %%
s3_client.put_object(
    Bucket=bucket_name,
    Key=file_name,
    Body=csv_buffer1.getvalue()
)

print(f"File uploaded to {bucket_name}/{file_name}")
# Out:
# File uploaded to etl-extractdata/customer_segmentation/categorical.csv

# %%
y_pd
# Out:
#        gender educationlevel maritalstatus accounttype preferredchannel  \
# 0           F       Master's      Divorced     Premium         In-store
# 1           F     Bachelor's        Single        Gold         In-store
# 2           M       Master's       Married       Basic         In-store
# 3           F       Master's      Divorced        Gold           Online
# 4           F       Master's       Married     Premium           Online
# ...       ...            ...           ...         ...              ...
# 199995      M     Bachelor's      Divorced        Gold         In-store
# 199996      M    High School      Divorced       Basic           Online
# 199997      M       Master's      Divorced       Basic         In-store
# 199998      F     Bachelor's      Divorced        Gold           Online
# 199999      M    High School      Divorced     Premium       Mobile App
#
#        productcategory region churnrisk campaignresponse  \
# ...
